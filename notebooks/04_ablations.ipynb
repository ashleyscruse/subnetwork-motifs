# %% [markdown]
# # 04: Ablation Studies
#
# - Topology-only vs full model
# - Features-only vs full model
# - Layer count sweep (2, 3, 4, 5)
# - Learning curves (10%, 25%, 50%, 75%, 100% of labels)

# %%
import pandas as pd
import matplotlib.pyplot as plt
