# %% [markdown]
# # 05: Motif Catalog
#
# Explore the significance testing results.
#
# - Distribution of Z-scores across all tested motifs
# - Significant motifs (after multiple testing correction)
# - MAPK cascade example: Ste11/Ste7/Fus3 feedforward loop
# - Human ortholog mapping for significant motifs

# %%
import pandas as pd
import matplotlib.pyplot as plt
