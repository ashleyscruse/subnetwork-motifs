# %% [markdown]
# # 01: Data Exploration
#
# Verify the downloaded datasets and compute summary statistics.
#
# **Key numbers to verify:**
# - ~203 TFs
# - ~6,000 target genes
# - ~450 duplicate pairs with fate labels
# - ~500 paralog groups

# %%
import pandas as pd
import matplotlib.pyplot as plt
