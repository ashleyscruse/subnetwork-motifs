# %% [markdown]
# # 03: Training Results
#
# Visualize GAT training results and compare against baselines.
#
# - AUC-ROC per fold
# - GAT vs uniform vs sequence-similarity vs random forest vs logistic regression
# - Predicted pi distribution

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
